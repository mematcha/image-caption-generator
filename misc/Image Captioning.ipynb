# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, GRU, Dense, Dropout, Add
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from nltk.translate.bleu_score import sentence_bleu
from scipy.spatial.distance import cosine
import pickle
import os
import glob
from PIL import Image
from tqdm import tqdm
# Out:
# 2024-10-27 15:24:38.160410: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load MSCOCO dataset - Replace this path with your MSCOCO path
dataset_path = "/Users/Aneesh/Downloads/captions_train2017.json"

# Preprocess captions
def preprocess_caption(caption):
    caption = caption.lower()
    caption = caption.replace("[^a-zA-Z]", " ")
    caption = "startseq " + caption + " endseq"
    return caption

# Load captions and preprocess
import json
with open(dataset_path, 'r') as f:
    captions_data = json.load(f)
    
captions = {}
for annot in captions_data['annotations']:
    img_id = annot['image_id']
    caption = preprocess_caption(annot['caption'])
    captions[img_id] = captions.get(img_id, []) + [caption]

# %%
# Load the InceptionV3 model and remove the last layer
inception_model = InceptionV3(weights='imagenet')
inception_model = Model(inception_model.input, inception_model.layers[-2].output)

def extract_features(filename, model):
    img = Image.open(filename)
    img = img.resize((299, 299))
    img = np.array(img)
    if img.shape == (299, 299, 3):
        img = np.expand_dims(img, axis=0)
        img = tf.keras.applications.inception_v3.preprocess_input(img)
        feature = model.predict(img, verbose=0)
        return feature.reshape(-1)
    return None

# Extract features for all images
image_dir = "/Users/Aneesh/Downloads/train2017"
features = {}
for img_file in tqdm(glob.glob(image_dir + '*.jpg')):
    img_id = int(os.path.basename(img_file).split('.')[0])
    features[img_id] = extract_features(img_file, inception_model)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# 0it [00:00, ?it/s]

# %%
# Prepare tokenizer
all_captions = [cap for caps in captions.values() for cap in caps]
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)

# Save the tokenizer for future use
with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

vocab_size = len(tokenizer.word_index) + 1
max_length = max(len(c.split()) for c in all_captions)

# Create sequences and pad them
def create_sequences(tokenizer, max_length, desc_list, photo):
    X1, X2, y = [], [], []
    for desc in desc_list:
        seq = tokenizer.texts_to_sequences([desc])[0]
        for i in range(1, len(seq)):
            in_seq, out_seq = seq[:i], seq[i]
            in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
            out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
            X1.append(photo)
            X2.append(in_seq)
            y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

# %%
# Define LSTM and GRU models
def define_model(vocab_size, max_length, embedding_dim=256, rnn_type="LSTM"):
    inputs1 = Input(shape=(2048,))
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(embedding_dim, activation='relu')(fe1)
    
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, embedding_dim, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    if rnn_type == "LSTM":
        se3 = LSTM(256)(se2)
    else:
        se3 = GRU(256)(se2)
    
    decoder1 = Add()([fe2, se3])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax')(decoder2)
    
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    return model

# Create models for both LSTM and GRU
lstm_model = define_model(vocab_size, max_length, rnn_type="LSTM")
gru_model = define_model(vocab_size, max_length, rnn_type="GRU")

# %%
for img_id, cap_list in tqdm(captions.items()):
    if img_id in features:
        img_features = features[img_id]
        X1, X2, y = create_sequences(tokenizer, max_length, cap_list, img_features)
        X1train.extend(X1)
        X2train.extend(X2)
        ytrain.extend(y)
    else:
        print(f"Image ID {img_id} not found in features.")
# Out:
#  43%|█████████████▊                  | 51182/118287 [00:00<00:00, 258211.08it/s]
# Image ID 203564 not found in features.
# Image ID 322141 not found in features.
# Image ID 16977 not found in features.
# Image ID 106140 not found in features.
# Image ID 571635 not found in features.
# Image ID 301837 not found in features.
# Image ID 315702 not found in features.
# Image ID 189634 not found in features.
# Image ID 472598 not found in features.
# Image ID 162113 not found in features.
# Image ID 126657 not found in features.
# Image ID 285421 not found in features.
# Image ID 71988 not found in features.
# Image ID 193622 not found in features.
# Image ID 459912 not found in features.
# Image ID 548498 not found in features.
# Image ID 52087 not found in features.
# Image ID 119964 not found in features.
# Image ID 230610 not found in features.
# Image ID 226419 not found in features.
# Image ID 218026 not found in features.
# Image ID 352538 not found in features.
# Image ID 202913 not found in features.
# Image ID 202658 not found in features.
# Image ID 79472 not found in features.
# Image ID 346071 not found in features.
# Image ID 6672 not found in features.
# Image ID 419074 not found in features.
# Image ID 382406 not found in features.
# Image ID 175948 not found in features.
# Image ID 573223 not found in features.
# Image ID 402514 not found in features.
# Image ID 407286 not found in features.
# Image ID 82673 not found in features.
# Image ID 141172 not found in features.
# Image ID 104326 not found in features.
# Image ID 581177 not found in features.
# Image ID 267802 not found in features.
# Image ID 208408 not found in features.
# Image ID 560591 not found in features.
# Image ID 507362 not found in features.
# Image ID 57429 not found in features.
# Image ID 153184 not found in features.
# Image ID 571970 not found in features.
# Image ID 133680 not found in features.
# Image ID 139011 not found in features.
# Image ID 505386 not found in features.
# Image ID 107990 not found in features.
# Image ID 527510 not found in features.
# Image ID 5247 not found in features.
# Image ID 107960 not found in features.
# Image ID 410627 not found in features.
# Image ID 232223 not found in features.
# Image ID 22793 not found in features.
# Image ID 436456 not found in features.
# Image ID 368402 not found in features.
# Image ID 135161 not found in features.
# Image ID 178761 not found in features.
# Image ID 491000 not found in features.
# Image ID 538092 not found in features.
# Image ID 205577 not found in features.
# Image ID 508672 not found in features.
# Image ID 334015 not found in features.
# Image ID 27842 not found in features.
# Image ID 358606 not found in features.
# Image ID 567730 not found in features.
# Image ID 61259 not found in features.
# Image ID 554037 not found in features.
# Image ID 5394 not found in features.
# Image ID 455384 not found in features.
# Image ID 249352 not found in features.
# Image ID 348306 not found in features.
# Image ID 475593 not found in features.
# Image ID 145523 not found in features.
# Image ID 143370 not found in features.
# Image ID 279806 not found in features.
# Image ID 59171 not found in features.
# Image ID 369826 not found in features.
# Image ID 400552 not found in features.
# Image ID 238836 not found in features.
# Image ID 264461 not found in features.
# Image ID 342387 not found in features.
# Image ID 488327 not found in features.
# Image ID 540860 not found in features.
# Image ID 172851 not found in features.
# Image ID 486194 not found in features.
# Image ID 236148 not found in features.
# Image ID 115930 not found in features.
# Image ID 75663 not found in features.
# Image ID 352794 not found in features.
# Image ID 175954 not found in features.
# Image ID 484751 not found in features.
# Image ID 457834 not found in features.
# Image ID 412151 not found in features.
# Image ID 427091 not found in features.
# Image ID 32203 not found in features.
# Image ID 525971 not found in features.
# Image ID 354572 not found in features.
# Image ID 185360 not found in features.
# Image ID 321064 not found in features.
# Image ID 263664 not found in features.
# Image ID 468508 not found in features.
# Image ID 31984 not found in features.
# Image ID 322791 not found in features.
# Image ID 295768 not found in features.
# Image ID 229067 not found in features.
# Image ID 156324 not found in features.
# Image ID 508605 not found in features.
# Image ID 268224 not found in features.
# Image ID 206260 not found in features.
# Image ID 489528 not found in features.
# Image ID 450308 not found in features.
# Image ID 446409 not found in features.
# Image ID 420958 not found in features.
# Image ID 523400 not found in features.
# Image ID 40986 not found in features.
# Image ID 8045 not found in features.
# Image ID 529691 not found in features.
# Image ID 482597 not found in features.
# Image ID 51191 not found in features.
# Image ID 249371 not found in features.
# Image ID 408364 not found in features.
# Image ID 267862 not found in features.
# Image ID 536321 not found in features.
# Image ID 148272 not found in features.
# Image ID 36450 not found in features.
# Image ID 138599 not found in features.
# Image ID 501055 not found in features.
# Image ID 363272 not found in features.
# Image ID 231846 not found in features.
# Image ID 260409 not found in features.
# Image ID 220704 not found in features.
# Image ID 158466 not found in features.
# Image ID 100138 not found in features.
# Image ID 349344 not found in features.
# Image ID 317639 not found in features.
# Image ID 556837 not found in features.
# Image ID 282346 not found in features.
# Image ID 477016 not found in features.
# Image ID 172710 not found in features.
# Image ID 214274 not found in features.
# Image ID 385757 not found in features.
# Image ID 181586 not found in features.
# Image ID 383464 not found in features.
# Image ID 552979 not found in features.
# Image ID 289714 not found in features.
# Image ID 425690 not found in features.
# Image ID 19523 not found in features.
# Image ID 510992 not found in features.
# Image ID 278237 not found in features.
# Image ID 319275 not found in features.
# Image ID 430750 not found in features.
# Image ID 370462 not found in features.
# Image ID 205570 not found in features.
# Image ID 443351 not found in features.
# Image ID 97790 not found in features.
# Image ID 375415 not found in features.
# Image ID 576981 not found in features.
# Image ID 124766 not found in features.
# Image ID 498547 not found in features.
# Image ID 561620 not found in features.
# Image ID 239985 not found in features.
# Image ID 43098 not found in features.
# Image ID 325374 not found in features.
# Image ID 568265 not found in features.
# Image ID 14297 not found in features.
# Image ID 30423 not found in features.
# Image ID 8180 not found in features.
# Image ID 207652 not found in features.
# Image ID 510150 not found in features.
# Image ID 436972 not found in features.
# Image ID 564911 not found in features.
# Image ID 373193 not found in features.
# Image ID 127585 not found in features.
# Image ID 349590 not found in features.
# Image ID 372413 not found in features.
# Image ID 102625 not found in features.
# Image ID 145093 not found in features.
# Image ID 100711 not found in features.
# Image ID 300216 not found in features.
# Image ID 306313 not found in features.
# Image ID 349804 not found in features.
# Image ID 548706 not found in features.
# Image ID 271206 not found in features.
# Image ID 369763 not found in features.
# Image ID 312724 not found in features.
# Image ID 322604 not found in features.
# Image ID 445002 not found in features.
# Image ID 39430 not found in features.
# Image ID 215708 not found in features.
# Image ID 123843 not found in features.
# Image ID 175024 not found in features.
# Image ID 106900 not found in features.
# Image ID 74132 not found in features.
# Image ID 428769 not found in features.
# Image ID 69236 not found in features.
# Image ID 262594 not found in features.
# Image ID 32054 not found in features.
# Image ID 56070 not found in features.
# Image ID 11334 not found in features.
# Image ID 81505 not found in features.
# Image ID 555472 not found in features.
# Image ID 468858 not found in features.
# Image ID 104381 not found in features.
# Image ID 525667 not found in features.
# Image ID 549386 not found in features.
# Image ID 237920 not found in features.
# Image ID 155997 not found in features.
# Image ID 5879 not found in features.
# Image ID 93959 not found in features.
# Image ID 251075 not found in features.
# Image ID 281950 not found in features.
# Image ID 370210 not found in features.
# Image ID 531111 not found in features.
# Image ID 499177 not found in features.
# Image ID 75118 not found in features.
# Image ID 90732 not found in features.
# Image ID 301574 not found in features.
# Image ID 241876 not found in features.
# Image ID 34474 not found in features.
# Image ID 364113 not found in features.
# Image ID 79920 not found in features.
# Image ID 494629 not found in features.
# Image ID 61422 not found in features.
# Image ID 146961 not found in features.
# Image ID 9288 not found in features.
# Image ID 136783 not found in features.
# Image ID 120157 not found in features.
# Image ID 193680 not found in features.
# Image ID 565635 not found in features.
# Image ID 561780 not found in features.
# Image ID 230600 not found in features.
# Image ID 69293 not found in features.
# Image ID 369979 not found in features.
# Image ID 21711 not found in features.
# Image ID 293153 not found in features.
# Image ID 20788 not found in features.
# Image ID 424378 not found in features.
# Image ID 400456 not found in features.
# Image ID 186697 not found in features.
# Image ID 336384 not found in features.
# Image ID 154419 not found in features.
# Image ID 331366 not found in features.
# Image ID 251639 not found in features.
# Image ID 372113 not found in features.
# Image ID 554625 not found in features.
# Image ID 297414 not found in features.
# Image ID 412693 not found in features.
# Image ID 442609 not found in features.
# Image ID 132901 not found in features.
# Image ID 75101 not found in features.
# Image ID 493753 not found in features.
# Image ID 521906 not found in features.
# Image ID 353982 not found in features.
# Image ID 85316 not found in features.
# Image ID 527260 not found in features.
# Image ID 85145 not found in features.
# Image ID 533900 not found in features.
# Image ID 102735 not found in features.
# Image ID 56752 not found in features.
# Image ID 522137 not found in features.
# Image ID 544713 not found in features.
# Image ID 448151 not found in features.
# Image ID 537955 not found in features.
# Image ID 327565 not found in features.
# Image ID 411564 not found in features.
# Image ID 438258 not found in features.
# Image ID 306444 not found in features.
# Image ID 139440 not found in features.
# Image ID 401411 not found in features.
# Image ID 31519 not found in features.
# Image ID 220255 not found in features.
# Image ID 383601 not found in features.
# Image ID 154324 not found in features.
# Image ID 368978 not found in features.
# Image ID 237428 not found in features.
# Image ID 5802 not found in features.
# Image ID 272015 not found in features.
# Image ID 108283 not found in features.
# Image ID 360673 not found in features.
# Image ID 465877 not found in features.
# Image ID 524954 not found in features.
# Image ID 242363 not found in features.
# Image ID 488943 not found in features.
# Image ID 396673 not found in features.
# Image ID 8218 not found in features.
# Image ID 140307 not found in features.
# Image ID 27065 not found in features.
# Image ID 264599 not found in features.
# Image ID 332653 not found in features.
# Image ID 239252 not found in features.
# Image ID 506906 not found in features.
# Image ID 34196 not found in features.
# Image ID 260627 not found in features.
# Image ID 13466 not found in features.
# Image ID 262514 not found in features.
# Image ID 352151 not found in features.
# Image ID 57703 not found in features.
# Image ID 199951 not found in features.
# Image ID 525420 not found in features.
# Image ID 567220 not found in features.
# Image ID 236535 not found in features.
# Image ID 568893 not found in features.
# Image ID 62483 not found in features.
# Image ID 137967 not found in features.
# Image ID 580255 not found in features.
# Image ID 99389 not found in features.
# Image ID 152649 not found in features.
# Image ID 294832 not found in features.
# Image ID 499281 not found in features.
# Image ID 73280 not found in features.
# Image ID 176828 not found in features.
# Image ID 288639 not found in features.
# Image ID 420490 not found in features.
# Image ID 528729 not found in features.
# Image ID 196047 not found in features.
# Image ID 147042 not found in features.
# Image ID 50411 not found in features.
# Image ID 43771 not found in features.
# Image ID 120021 not found in features.
# Image ID 27517 not found in features.
# Image ID 92678 not found in features.
# Image ID 175942 not found in features.
# Image ID 279343 not found in features.
# Image ID 486521 not found in features.
# Image ID 564003 not found in features.
# Image ID 283910 not found in features.
# Image ID 497099 not found in features.
# Image ID 318361 not found in features.
# Image ID 115229 not found in features.
# Image ID 148766 not found in features.
# Image ID 562090 not found in features.
# Image ID 166003 not found in features.
# Image ID 136793 not found in features.
# Image ID 383777 not found in features.
# Image ID 422326 not found in features.
# Image ID 162280 not found in features.
# Image ID 211491 not found in features.
# Image ID 160345 not found in features.
# Image ID 231236 not found in features.
# Image ID 264964 not found in features.
# Image ID 28389 not found in features.
# Image ID 307993 not found in features.
# Image ID 351711 not found in features.
# Image ID 449279 not found in features.
# Image ID 386613 not found in features.
# Image ID 391132 not found in features.
# Image ID 421195 not found in features.
# Image ID 555983 not found in features.
# Image ID 544975 not found in features.
# Image ID 370165 not found in features.
# Image ID 514537 not found in features.
# Image ID 292648 not found in features.
# Image ID 246233 not found in features.
# Image ID 170232 not found in features.
# Image ID 524202 not found in features.
# Image ID 208169 not found in features.
# Image ID 376177 not found in features.
# Image ID 523953 not found in features.
# Image ID 391837 not found in features.
# Image ID 118965 not found in features.
# Image ID 190829 not found in features.
# Image ID 314328 not found in features.
# Image ID 538359 not found in features.
# Image ID 482187 not found in features.
# Image ID 538497 not found in features.
# Image ID 172843 not found in features.
# Image ID 140006 not found in features.
# Image ID 574145 not found in features.
# Image ID 546642 not found in features.
# Image ID 184531 not found in features.
# Image ID 49428 not found in features.
# Image ID 499391 not found in features.
# Image ID 254644 not found in features.
# Image ID 325357 not found in features.
# Image ID 283498 not found in features.
# Image ID 107907 not found in features.
# Image ID 57072 not found in features.
# Image ID 526401 not found in features.
# Image ID 246613 not found in features.
# Image ID 56205 not found in features.
# Image ID 540669 not found in features.
# Image ID 67252 not found in features.
# Image ID 309071 not found in features.
# Image ID 283904 not found in features.
# Image ID 245818 not found in features.
# Image ID 317320 not found in features.
# Image ID 67327 not found in features.
# Image ID 72077 not found in features.
# Image ID 75560 not found in features.
# Image ID 315173 not found in features.
# Image ID 238090 not found in features.
# Image ID 34811 not found in features.
# Image ID 451202 not found in features.
# Image ID 374950 not found in features.
# Image ID 143582 not found in features.
# Image ID 430774 not found in features.
# Image ID 144941 not found in features.
# Image ID 488278 not found in features.
# Image ID 74920 not found in features.
# Image ID 447787 not found in features.
# Image ID 477688 not found in features.
# Image ID 148737 not found in features.
# Image ID 374743 not found in features.
# Image ID 10800 not found in features.
# Image ID 360434 not found in features.
# Image ID 167443 not found in features.
# Image ID 2881 not found in features.
# Image ID 80737 not found in features.
# Image ID 337403 not found in features.
# Image ID 371117 not found in features.
# Image ID 506151 not found in features.
# Image ID 73009 not found in features.
# Image ID 75051 not found in features.
# Image ID 384036 not found in features.
# Image ID 490927 not found in features.
# Image ID 298784 not found in features.
# Image ID 196758 not found in features.
# Image ID 537548 not found in features.
# Image ID 474430 not found in features.
# Image ID 519649 not found in features.
# Image ID 163333 not found in features.
# Image ID 159377 not found in features.
# Image ID 401556 not found in features.
# Image ID 48419 not found in features.
# Image ID 287151 not found in features.
# Image ID 139291 not found in features.
# Image ID 242611 not found in features.
# Image ID 419978 not found in features.
# Image ID 257996 not found in features.
# Image ID 411685 not found in features.
# Image ID 15918 not found in features.
# Image ID 205533 not found in features.
# Image ID 252911 not found in features.
# Image ID 544237 not found in features.
# Image ID 120428 not found in features.
# Image ID 64088 not found in features.
# Image ID 436467 not found in features.
# Image ID 523297 not found in features.
# Image ID 469134 not found in features.
# Image ID 314370 not found in features.
# Image ID 122317 not found in features.
# Image ID 539478 not found in features.
# Image ID 542211 not found in features.
# Image ID 264659 not found in features.
# Image ID 435444 not found in features.
# Image ID 572733 not found in features.
# Image ID 128842 not found in features.
# Image ID 342515 not found in features.
# Image ID 221737 not found in features.
# Image ID 258680 not found in features.
# Image ID 170389 not found in features.
# Image ID 506577 not found in features.
# Image ID 261679 not found in features.
# Image ID 576305 not found in features.
# Image ID 316429 not found in features.
# Image ID 113588 not found in features.
# Image ID 263163 not found in features.
# Image ID 557016 not found in features.
# Image ID 54679 not found in features.
# Image ID 106335 not found in features.
# Image ID 8718 not found in features.
# Image ID 245902 not found in features.
# Image ID 210060 not found in features.
# Image ID 580388 not found in features.
# Image ID 92963 not found in features.
# Image ID 206176 not found in features.
# Image ID 559252 not found in features.
# Image ID 347142 not found in features.
# Image ID 358765 not found in features.
# Image ID 101172 not found in features.
# Image ID 195179 not found in features.
# Image ID 364243 not found in features.
# Image ID 321432 not found in features.
# Image ID 53434 not found in features.
# Image ID 775 not found in features.
# Image ID 215408 not found in features.
# Image ID 47775 not found in features.
# Image ID 469492 not found in features.
# Image ID 383065 not found in features.
# Image ID 310121 not found in features.
# Image ID 287554 not found in features.
# Image ID 69773 not found in features.
# Image ID 484397 not found in features.
# Image ID 461017 not found in features.
# Image ID 285007 not found in features.
# Image ID 550527 not found in features.
# Image ID 356528 not found in features.
# Image ID 436875 not found in features.
# Image ID 127496 not found in features.
# Image ID 533039 not found in features.
# Image ID 281676 not found in features.
# Image ID 3035 not found in features.
# Image ID 37322 not found in features.
# Image ID 168775 not found in features.
# Image ID 142340 not found in features.
# Image ID 497375 not found in features.
# Image ID 170393 not found in features.
# Image ID 208871 not found in features.
# Image ID 89281 not found in features.
# Image ID 428305 not found in features.
# Image ID 556545 not found in features.
# Image ID 253441 not found in features.
# Image ID 556349 not found in features.
# Image ID 440124 not found in features.
# Image ID 70889 not found in features.
# Image ID 531061 not found in features.
# Image ID 365822 not found in features.
# Image ID 293228 not found in features.
# Image ID 577377 not found in features.
# Image ID 36124 not found in features.
# Image ID 368349 not found in features.
# Image ID 463555 not found in features.
# Image ID 161603 not found in features.
# Image ID 77102 not found in features.
# Image ID 441473 not found in features.
# Image ID 377867 not found in features.
# Image ID 511622 not found in features.
# Image ID 19358 not found in features.
# Image ID 425266 not found in features.
# Image ID 238147 not found in features.
# Image ID 278295 not found in features.
# Image ID 538319 not found in features.
# Image ID 467887 not found in features.
# Image ID 112915 not found in features.
# Image ID 137330 not found in features.
# Image ID 84980 not found in features.
# Image ID 75001 not found in features.
# Image ID 145448 not found in features.
# Image ID 44361 not found in features.
# Image ID 24996 not found in features.
# Image ID 258985 not found in features.
# Image ID 204805 not found in features.
# Image ID 265574 not found in features.
# Image ID 93791 not found in features.
# Image ID 545162 not found in features.
# Image ID 426840 not found in features.
# Image ID 358103 not found in features.
# Image ID 153445 not found in features.
# Image ID 135671 not found in features.
# Image ID 68852 not found in features.
# Image ID 406201 not found in features.
# Image ID 580543 not found in features.
# Image ID 501385 not found in features.
# Image ID 561088 not found in features.
# Image ID 124210 not found in features.
# Image ID 327433 not found in features.
# Image ID 230226 not found in features.
# Image ID 217039 not found in features.
# Image ID 51628 not found in features.
# Image ID 374060 not found in features.
# Image ID 185276 not found in features.
# Image ID 380247 not found in features.
# Image ID 484531 not found in features.
# Image ID 79446 not found in features.
# Image ID 554749 not found in features.
# Image ID 295574 not found in features.
# Image ID 243386 not found in features.
# Image ID 520941 not found in features.
# Image ID 384007 not found in features.
# Image ID 265313 not found in features.
# Image ID 197792 not found in features.
# Image ID 514116 not found in features.
# Image ID 577212 not found in features.
# Image ID 82363 not found in features.
# Image ID 416668 not found in features.
# Image ID 431113 not found in features.
# Image ID 17235 not found in features.
# Image ID 488349 not found in features.
# Image ID 345930 not found in features.
# Image ID 570001 not found in features.
# Image ID 213429 not found in features.
# Image ID 349101 not found in features.
# Image ID 422416 not found in features.
# Image ID 96946 not found in features.
# Image ID 237060 not found in features.
# Image ID 577912 not found in features.
# Image ID 559303 not found in features.
# Image ID 444382 not found in features.
# Image ID 384111 not found in features.
# Image ID 482974 not found in features.
# Image ID 19028 not found in features.
# Image ID 230190 not found in features.
# Image ID 35768 not found in features.
# Image ID 258266 not found in features.
# Image ID 187680 not found in features.
# Image ID 369190 not found in features.
# Image ID 427639 not found in features.
# Image ID 482707 not found in features.
# Image ID 170630 not found in features.
# Image ID 399879 not found in features.
# Image ID 499802 not found in features.
# Image ID 117869 not found in features.
# Image ID 432397 not found in features.
# Image ID 292278 not found in features.
# Image ID 464534 not found in features.
# Image ID 553436 not found in features.
# Image ID 386766 not found in features.
# Image ID 196521 not found in features.
# Image ID 479008 not found in features.
# Image ID 532686 not found in features.
# Image ID 361386 not found in features.
# Image ID 32124 not found in features.
# Image ID 478120 not found in features.
# Image ID 283833 not found in features.
# Image ID 172285 not found in features.
# Image ID 118097 not found in features.
# Image ID 412184 not found in features.
# Image ID 240565 not found in features.
# Image ID 293218 not found in features.
# Image ID 169111 not found in features.
# Image ID 11721 not found in features.
# Image ID 13296 not found in features.
# Image ID 241867 not found in features.
# Image ID 490847 not found in features.
# Image ID 88682 not found in features.
# Image ID 559270 not found in features.
# Image ID 121430 not found in features.
# Image ID 276387 not found in features.
# Image ID 195894 not found in features.
# Image ID 434891 not found in features.
# Image ID 82312 not found in features.
# Image ID 487181 not found in features.
# Image ID 515422 not found in features.
# Image ID 36492 not found in features.
# Image ID 16730 not found in features.
# Image ID 80017 not found in features.
# Image ID 509811 not found in features.
# Image ID 484080 not found in features.
# Image ID 301827 not found in features.
# Image ID 455943 not found in features.
# Image ID 18975 not found in features.
# Image ID 133002 not found in features.
# Image ID 8292 not found in features.
# Image ID 283190 not found in features.
# Image ID 542183 not found in features.
# Image ID 409500 not found in features.
# Image ID 443652 not found in features.
# Image ID 215255 not found in features.
# Image ID 314016 not found in features.
# Image ID 3466 not found in features.
# Image ID 308677 not found in features.
# Image ID 35897 not found in features.
# Image ID 28714 not found in features.
# Image ID 498350 not found in features.
# Image ID 363286 not found in features.
# Image ID 108838 not found in features.
# Image ID 196415 not found in features.
# Image ID 316183 not found in features.
# Image ID 48708 not found in features.
# Image ID 98194 not found in features.
# Image ID 487338 not found in features.
# Image ID 120340 not found in features.
# Image ID 25853 not found in features.
# Image ID 202573 not found in features.
# Image ID 575032 not found in features.
# Image ID 381551 not found in features.
# Image ID 319345 not found in features.
# Image ID 62200 not found in features.
# Image ID 567636 not found in features.
# Image ID 460567 not found in features.
# Image ID 204930 not found in features.
# Image ID 155617 not found in features.
# Image ID 470313 not found in features.
# Image ID 276631 not found in features.
# Image ID 48185 not found in features.
# Image ID 554433 not found in features.
# Image ID 195955 not found in features.
# Image ID 241113 not found in features.
# Image ID 79930 not found in features.
# Image ID 552074 not found in features.
# Image ID 93331 not found in features.
# Image ID 60760 not found in features.
# Image ID 570981 not found in features.
# Image ID 367336 not found in features.
# Image ID 183379 not found in features.
# Image ID 253986 not found in features.
# Image ID 939 not found in features.
# Image ID 441695 not found in features.
# Image ID 110560 not found in features.
# Image ID 532285 not found in features.
# Image ID 65057 not found in features.
# Image ID 330676 not found in features.
# Image ID 531234 not found in features.
# Image ID 372220 not found in features.
# Image ID 170041 not found in features.
# Image ID 243456 not found in features.
# Image ID 83049 not found in features.
# Image ID 160529 not found in features.
# Image ID 127119 not found in features.
# Image ID 358302 not found in features.
# Image ID 278509 not found in features.
# Image ID 466118 not found in features.
# Image ID 395978 not found in features.
# Image ID 81922 not found in features.
# Image ID 318161 not found in features.
# Image ID 264121 not found in features.
# Image ID 393659 not found in features.
# Image ID 545317 not found in features.
# Image ID 326937 not found in features.
# Image ID 495984 not found in features.
# Image ID 346904 not found in features.
# Image ID 55955 not found in features.
# Image ID 53431 not found in features.
# Image ID 370138 not found in features.
# Image ID 325958 not found in features.
# Image ID 246004 not found in features.
# Image ID 511145 not found in features.
# Image ID 540354 not found in features.
# Image ID 99518 not found in features.
# Image ID 283816 not found in features.
# Image ID 434060 not found in features.
# Image ID 386313 not found in features.
# Image ID 263961 not found in features.
# Image ID 125870 not found in features.
# Image ID 432605 not found in features.
# Image ID 210883 not found in features.
# Image ID 482382 not found in features.
# Image ID 560879 not found in features.
# Image ID 210228 not found in features.
# Image ID 53484 not found in features.
# Image ID 45208 not found in features.
# Image ID 471858 not found in features.
# Image ID 509807 not found in features.
# Image ID 486400 not found in features.
# Image ID 331686 not found in features.
# Image ID 570138 not found in features.
# Image ID 439837 not found in features.
# Image ID 568717 not found in features.
# Image ID 263700 not found in features.
# Image ID 463825 not found in features.
# Image ID 541783 not found in features.
# Image ID 392320 not found in features.
# Image ID 89391 not found in features.
# Image ID 173530 not found in features.
# Image ID 22718 not found in features.
# Image ID 95736 not found in features.
# Image ID 117458 not found in features.
# Image ID 569652 not found in features.
# Image ID 347740 not found in features.
# Image ID 284153 not found in features.
# Image ID 566038 not found in features.
# Image ID 46011 not found in features.
# Image ID 543203 not found in features.
# Image ID 295756 not found in features.
# Image ID 26522 not found in features.
# Image ID 427796 not found in features.
# Image ID 581654 not found in features.
# Image ID 571518 not found in features.
# Image ID 254172 not found in features.
# Image ID 304447 not found in features.
# Image ID 135116 not found in features.
# Image ID 332607 not found in features.
# Image ID 146112 not found in features.
# Image ID 535483 not found in features.
# Image ID 315191 not found in features.
# Image ID 105177 not found in features.
# Image ID 453093 not found in features.
# Image ID 72810 not found in features.
# Image ID 337044 not found in features.
# Image ID 391371 not found in features.
# Image ID 541274 not found in features.
# Image ID 7288 not found in features.
# Image ID 410350 not found in features.
# Image ID 449466 not found in features.
# Image ID 150144 not found in features.
# Image ID 111076 not found in features.
# Image ID 173350 not found in features.
# Image ID 579593 not found in features.
# Image ID 150538 not found in features.
# Image ID 560373 not found in features.
# Image ID 133503 not found in features.
# Image ID 562150 not found in features.
# Image ID 347925 not found in features.
# Image ID 385181 not found in features.
# Image ID 200365 not found in features.
# Image ID 543660 not found in features.
# Image ID 378727 not found in features.
# Image ID 541086 not found in features.
# Image ID 558642 not found in features.
# Image ID 255654 not found in features.
# Image ID 436130 not found in features.
# Image ID 561578 not found in features.
# Image ID 178084 not found in features.
# Image ID 43997 not found in features.
# Image ID 91263 not found in features.
# Image ID 312175 not found in features.
# Image ID 553588 not found in features.
# Image ID 99425 not found in features.
# Image ID 303321 not found in features.
# Image ID 497504 not found in features.
# Image ID 84064 not found in features.
# Image ID 31019 not found in features.
# Image ID 423769 not found in features.
# Image ID 35525 not found in features.
# Image ID 465664 not found in features.
# Image ID 127668 not found in features.
# Image ID 85632 not found in features.
# Image ID 167724 not found in features.
# Image ID 375916 not found in features.
# Image ID 177101 not found in features.
# Image ID 93703 not found in features.
# Image ID 512334 not found in features.
# Image ID 43092 not found in features.
# Image ID 340511 not found in features.
# Image ID 415874 not found in features.
# Image ID 556230 not found in features.
# Image ID 394517 not found in features.
# Image ID 263687 not found in features.
# Image ID 426053 not found in features.
# Image ID 271970 not found in features.
# Image ID 5412 not found in features.
# Image ID 471488 not found in features.
# Image ID 356145 not found in features.
# Image ID 234590 not found in features.
# Image ID 94745 not found in features.
# Image ID 320249 not found in features.
# Image ID 401623 not found in features.
# Image ID 204507 not found in features.
# Image ID 241888 not found in features.
# Image ID 413096 not found in features.
# Image ID 380756 not found in features.
# Image ID 334291 not found in features.
# Image ID 14921 not found in features.
# Image ID 454203 not found in features.
# Image ID 51844 not found in features.
# Image ID 53838 not found in features.
# Image ID 515289 not found in features.
# Image ID 488755 not found in features.
# Image ID 262394 not found in features.
# Image ID 570349 not found in features.
# Image ID 309022 not found in features.
# Image ID 345389 not found in features.
# Image ID 352000 not found in features.
# Image ID 299042 not found in features.
# Image ID 280320 not found in features.
# Image ID 565296 not found in features.
# Image ID 484723 not found in features.
# Image ID 483994 not found in features.
# Image ID 363048 not found in features.
# Image ID 195267 not found in features.
# Image ID 86426 not found in features.
# Image ID 2061 not found in features.
# Image ID 183895 not found in features.
# Image ID 181524 not found in features.
# Image ID 438999 not found in features.
# Image ID 402626 not found in features.
# Image ID 65258 not found in features.
# Image ID 165750 not found in features.
# Image ID 507958 not found in features.
# Image ID 57454 not found in features.
# Image ID 556345 not found in features.
# Image ID 102668 not found in features.
# Image ID 24061 not found in features.
# Image ID 504900 not found in features.
# Image ID 315868 not found in features.
# Image ID 578632 not found in features.
# Image ID 557135 not found in features.
# Image ID 107922 not found in features.
# Image ID 339974 not found in features.
# Image ID 54305 not found in features.
# Image ID 560367 not found in features.
# Image ID 563311 not found in features.
# Image ID 448765 not found in features.
# Image ID 525344 not found in features.
# Image ID 79878 not found in features.
# Image ID 41271 not found in features.
# Image ID 497969 not found in features.
# Image ID 151911 not found in features.
# Image ID 142261 not found in features.
# Image ID 344488 not found in features.
# Image ID 360573 not found in features.
# Image ID 267135 not found in features.
# Image ID 348140 not found in features.
# Image ID 290521 not found in features.
# Image ID 550864 not found in features.
# Image ID 190734 not found in features.
# Image ID 523373 not found in features.
# Image ID 489248 not found in features.
# Image ID 429074 not found in features.
# Image ID 111099 not found in features.
# Image ID 283505 not found in features.
# Image ID 388026 not found in features.
# Image ID 111789 not found in features.
# Image ID 436653 not found in features.
# Image ID 533003 not found in features.
# Image ID 280619 not found in features.
# Image ID 493695 not found in features.
# Image ID 522198 not found in features.
# Image ID 296243 not found in features.
# Image ID 64723 not found in features.
# Image ID 288923 not found in features.
# Image ID 189939 not found in features.
# Image ID 309925 not found in features.
# Image ID 434467 not found in features.
# Image ID 320641 not found in features.
# Image ID 67956 not found in features.
# Image ID 91636 not found in features.
# Image ID 41839 not found in features.
# Image ID 106351 not found in features.
# Image ID 378163 not found in features.
# Image ID 502311 not found in features.
# Image ID 5476 not found in features.
# Image ID 547003 not found in features.
# Image ID 96107 not found in features.
# Image ID 357475 not found in features.
# Image ID 252203 not found in features.
# Image ID 139169 not found in features.
# Image ID 523526 not found in features.
# Image ID 10954 not found in features.
# Image ID 573072 not found in features.
# Image ID 108679 not found in features.
# Image ID 11182 not found in features.
# Image ID 513064 not found in features.
# Image ID 245013 not found in features.
# Image ID 281111 not found in features.
# Image ID 338098 not found in features.
# Image ID 281533 not found in features.
# Image ID 483249 not found in features.
# Image ID 410319 not found in features.
# Image ID 282658 not found in features.
# Image ID 145019 not found in features.
# Image ID 485916 not found in features.
# Image ID 266070 not found in features.
# Image ID 527506 not found in features.
# Image ID 66879 not found in features.
# Image ID 543112 not found in features.
# Image ID 318405 not found in features.
# Image ID 233079 not found in features.
# Image ID 396204 not found in features.
# Image ID 285742 not found in features.
# Image ID 566249 not found in features.
# Image ID 462565 not found in features.
# Image ID 255795 not found in features.
# Image ID 521877 not found in features.
# Image ID 555023 not found in features.
# Image ID 528962 not found in features.
# Image ID 250790 not found in features.
# Image ID 261603 not found in features.
# Image ID 45976 not found in features.
# Image ID 111014 not found in features.
# Image ID 135613 not found in features.
# Image ID 278338 not found in features.
# Image ID 319285 not found in features.
# Image ID 567171 not found in features.
# Image ID 148968 not found in features.
# Image ID 415967 not found in features.
# Image ID 31000 not found in features.
# Image ID 398385 not found in features.
# Image ID 51476 not found in features.
# Image ID 207853 not found in features.
# Image ID 478077 not found in features.
# Image ID 302159 not found in features.
# Image ID 179930 not found in features.
# Image ID 562592 not found in features.
# Image ID 204757 not found in features.
# Image ID 469719 not found in features.
# Image ID 275270 not found in features.
# Image ID 338044 not found in features.
# Image ID 222494 not found in features.
# Image ID 368541 not found in features.
# Image ID 237568 not found in features.
# Image ID 62443 not found in features.
# Image ID 519479 not found in features.
# Image ID 306404 not found in features.
# Image ID 257448 not found in features.
# Image ID 164 not found in features.
# Image ID 267861 not found in features.
# Image ID 469638 not found in features.
# Image ID 246265 not found in features.
# Image ID 10114 not found in features.
# Image ID 371683 not found in features.
# Image ID 392650 not found in features.
# Image ID 579602 not found in features.
# Image ID 23623 not found in features.
# Image ID 180787 not found in features.
# Image ID 467475 not found in features.
# Image ID 95772 not found in features.
# Image ID 453020 not found in features.
# Image ID 255482 not found in features.
# Image ID 188651 not found in features.
# Image ID 370090 not found in features.
# Image ID 327514 not found in features.
# Image ID 428234 not found in features.
# Image ID 213932 not found in features.
# Image ID 462026 not found in features.
# Image ID 401783 not found in features.
# Image ID 168512 not found in features.
# Image ID 431236 not found in features.
# Image ID 172911 not found in features.
# Image ID 484432 not found in features.
# Image ID 414156 not found in features.
# Image ID 320703 not found in features.
# Image ID 555686 not found in features.
# Image ID 253223 not found in features.
# Image ID 579468 not found in features.
# Image ID 255248 not found in features.
# Image ID 456328 not found in features.
# Image ID 390241 not found in features.
# Image ID 564699 not found in features.
# Image ID 577796 not found in features.
# Image ID 143653 not found in features.
# Image ID 493235 not found in features.
# Image ID 526186 not found in features.
# Image ID 115162 not found in features.
# Image ID 4554 not found in features.
# Image ID 128373 not found in features.
# Image ID 245462 not found in features.
# Image ID 290532 not found in features.
# Image ID 370842 not found in features.
# Image ID 303520 not found in features.
# Image ID 58364 not found in features.
# Image ID 560948 not found in features.
# Image ID 377845 not found in features.
# Image ID 556278 not found in features.
# Image ID 42970 not found in features.
# Image ID 30707 not found in features.
# Image ID 473935 not found in features.
# Image ID 493843 not found in features.
# Image ID 150685 not found in features.
# Image ID 77296 not found in features.
# Image ID 176474 not found in features.
# Image ID 191842 not found in features.
# Image ID 143908 not found in features.
# Image ID 447546 not found in features.
# Image ID 306108 not found in features.
# Image ID 270376 not found in features.
# Image ID 341659 not found in features.
# Image ID 1525 not found in features.
# Image ID 135117 not found in features.
# Image ID 291833 not found in features.
# Image ID 403013 not found in features.
# Image ID 25972 not found in features.
# Image ID 455528 not found in features.
# Image ID 503790 not found in features.
# Image ID 185904 not found in features.
# Image ID 291930 not found in features.
# Image ID 98280 not found in features.
# Image ID 332908 not found in features.
# Image ID 444270 not found in features.
# Image ID 531069 not found in features.
# Image ID 529069 not found in features.
# Image ID 429633 not found in features.
# Image ID 152543 not found in features.
# Image ID 438024 not found in features.
# Image ID 79465 not found in features.
# Image ID 59463 not found in features.
# Image ID 154587 not found in features.
# Image ID 212074 not found in features.
# Image ID 82229 not found in features.
# Image ID 533026 not found in features.
# Image ID 251098 not found in features.
# Image ID 347253 not found in features.
# Image ID 429323 not found in features.
# Image ID 423767 not found in features.
# Image ID 261062 not found in features.
# Image ID 540694 not found in features.
# Image ID 378448 not found in features.
# Image ID 305545 not found in features.
# Image ID 183249 not found in features.
# Image ID 117037 not found in features.
# Image ID 321742 not found in features.
# Image ID 151988 not found in features.
# Image ID 315601 not found in features.
# Image ID 29709 not found in features.
# Image ID 75283 not found in features.
# Image ID 171717 not found in features.
# Image ID 126876 not found in features.
# Image ID 415672 not found in features.
# Image ID 334140 not found in features.
# Image ID 456323 not found in features.
# Image ID 460812 not found in features.
# Image ID 27390 not found in features.
# Image ID 433504 not found in features.
# Image ID 239355 not found in features.
# Image ID 293964 not found in features.
# Image ID 424445 not found in features.
# Image ID 193599 not found in features.
# Image ID 84474 not found in features.
# Image ID 580829 not found in features.
# Image ID 25685 not found in features.
# Image ID 141086 not found in features.
# Image ID 414379 not found in features.
# Image ID 373574 not found in features.
# Image ID 369259 not found in features.
# Image ID 256983 not found in features.
# Image ID 12101 not found in features.
# Image ID 348092 not found in features.
# Image ID 202040 not found in features.
# Image ID 332625 not found in features.
# Image ID 395463 not found in features.
# Image ID 429497 not found in features.
# Image ID 516868 not found in features.
# Image ID 94140 not found in features.
# Image ID 268259 not found in features.
# Image ID 104837 not found in features.
# Image ID 475923 not found in features.
# Image ID 418816 not found in features.
# Image ID 400945 not found in features.
# Image ID 79966 not found in features.
# Image ID 517128 not found in features.
# Image ID 24924 not found in features.
# Image ID 474519 not found in features.
# Image ID 109045 not found in features.
# Image ID 529159 not found in features.
# Image ID 552610 not found in features.
# Image ID 115709 not found in features.
# Image ID 450206 not found in features.
# Image ID 306936 not found in features.
# Image ID 507249 not found in features.
# Image ID 212525 not found in features.
# Image ID 88634 not found in features.
# Image ID 521542 not found in features.
# Image ID 482210 not found in features.
# Image ID 556025 not found in features.
# Image ID 243857 not found in features.
# Image ID 393858 not found in features.
# Image ID 47873 not found in features.
# Image ID 352196 not found in features.
# Image ID 555648 not found in features.
# Image ID 132861 not found in features.
# Image ID 150088 not found in features.
# Image ID 21232 not found in features.
# Image ID 91416 not found in features.
# Image ID 27285 not found in features.
# Image ID 143576 not found in features.
# Image ID 459219 not found in features.
# Image ID 517548 not found in features.
# Image ID 441841 not found in features.
# Image ID 191691 not found in features.
# Image ID 561037 not found in features.
# Image ID 561187 not found in features.
# Image ID 562356 not found in features.
# Image ID 145032 not found in features.
# Image ID 486008 not found in features.
# Image ID 1146 not found in features.
# Image ID 411908 not found in features.
# Image ID 437556 not found in features.
# Image ID 326582 not found in features.
# Image ID 434958 not found in features.
# Image ID 391343 not found in features.
# Image ID 232488 not found in features.
# Image ID 19157 not found in features.
# Image ID 50655 not found in features.
# Image ID 542611 not found in features.
# Image ID 311887 not found in features.
# Image ID 553935 not found in features.
# Image ID 262672 not found in features.
# Image ID 313948 not found in features.
# Image ID 89188 not found in features.
# Image ID 264976 not found in features.
# Image ID 355221 not found in features.
# Image ID 553698 not found in features.
# Image ID 77811 not found in features.
# Image ID 50713 not found in features.
# Image ID 13876 not found in features.
# Image ID 63240 not found in features.
# Image ID 531967 not found in features.
# Image ID 295199 not found in features.
# Image ID 231093 not found in features.
# Image ID 337120 not found in features.
# Image ID 151347 not found in features.
# Image ID 11081 not found in features.
# Image ID 212351 not found in features.
# Image ID 74 not found in features.
# Image ID 562139 not found in features.
# Image ID 234697 not found in features.
# Image ID 435316 not found in features.
# Image ID 325356 not found in features.
# Image ID 343708 not found in features.
# Image ID 84447 not found in features.
# Image ID 533548 not found in features.
# Image ID 154420 not found in features.
# Image ID 369485 not found in features.
# Image ID 577030 not found in features.
# Image ID 543090 not found in features.
# Image ID 546687 not found in features.
# Image ID 257685 not found in features.
# Image ID 126192 not found in features.
# Image ID 86320 not found in features.
# Image ID 295303 not found in features.
# Image ID 101456 not found in features.
# Image ID 49683 not found in features.
# Image ID 63882 not found in features.
# Image ID 405526 not found in features.
# Image ID 104715 not found in features.
# Image ID 268092 not found in features.
# Image ID 342142 not found in features.
# Image ID 38732 not found in features.
# Image ID 41397 not found in features.
# Image ID 455261 not found in features.
# Image ID 106392 not found in features.
# Image ID 337815 not found in features.
# Image ID 521587 not found in features.
# Image ID 251124 not found in features.
# Image ID 276149 not found in features.
# Image ID 179311 not found in features.
# Image ID 286662 not found in features.
# Image ID 520251 not found in features.
# Image ID 479440 not found in features.
# Image ID 356533 not found in features.
# Image ID 138246 not found in features.
# Image ID 114726 not found in features.
# Image ID 12343 not found in features.
# Image ID 235380 not found in features.
# Image ID 543525 not found in features.
# Image ID 467966 not found in features.
# Image ID 262386 not found in features.
# Image ID 89099 not found in features.
# Image ID 463459 not found in features.
# Image ID 366031 not found in features.
# Image ID 551170 not found in features.
# Image ID 103035 not found in features.
# Image ID 232455 not found in features.
# Image ID 40446 not found in features.
# Image ID 567693 not found in features.
# Image ID 357096 not found in features.
# Image ID 190227 not found in features.
# Image ID 142386 not found in features.
# Image ID 81943 not found in features.
# Image ID 12326 not found in features.
# Image ID 566576 not found in features.
# Image ID 274959 not found in features.
# Image ID 484028 not found in features.
# Image ID 337517 not found in features.
# Image ID 303928 not found in features.
# Image ID 162249 not found in features.
# Image ID 472621 not found in features.
# Image ID 60623 not found in features.
# Image ID 421307 not found in features.
# Image ID 360678 not found in features.
# Image ID 74743 not found in features.
# Image ID 107304 not found in features.
# Image ID 333683 not found in features.
# Image ID 105303 not found in features.
# ...
# Image ID 142786 not found in features.
# Image ID 184705 not found in features.
# Image ID 555574 not found in features.
# Image ID 525128 not found in features.
# Image ID 363433 not found in features.
# Image ID 20039 not found in features.
# Image ID 57749 not found in features.
# Image ID 567332 not found in features.
# Image ID 34608 not found in features.
# Image ID 241027 not found in features.
# Image ID 309585 not found in features.
# Image ID 345345 not found in features.
# Image ID 562488 not found in features.
# Image ID 49643 not found in features.
# Image ID 178935 not found in features.
# Image ID 460031 not found in features.
# Image ID 81555 not found in features.
# Image ID 209791 not found in features.
# Image ID 575772 not found in features.
# Image ID 580971 not found in features.
# Image ID 57979 not found in features.
# Image ID 454996 not found in features.
# Image ID 560392 not found in features.
# Image ID 336021 not found in features.
# Image ID 63330 not found in features.
# Image ID 192111 not found in features.
# Image ID 30731 not found in features.
# Image ID 352886 not found in features.
# Image ID 386542 not found in features.
# Image ID 235741 not found in features.
# Image ID 476465 not found in features.
# Image ID 203621 not found in features.
# Image ID 534016 not found in features.
# Image ID 404172 not found in features.
# Image ID 83651 not found in features.
# Image ID 426076 not found in features.
# Image ID 237031 not found in features.
# Image ID 253528 not found in features.
# Image ID 453472 not found in features.
# Image ID 369697 not found in features.
# Image ID 437517 not found in features.
# Image ID 373779 not found in features.
# Image ID 165470 not found in features.
# Image ID 498587 not found in features.
# Image ID 157792 not found in features.
# Image ID 349931 not found in features.
# Image ID 228172 not found in features.
# Image ID 37011 not found in features.
# Image ID 126321 not found in features.
# Image ID 222753 not found in features.
# Image ID 311011 not found in features.
# Image ID 463140 not found in features.
# Image ID 212941 not found in features.
# Image ID 361255 not found in features.
# Image ID 165859 not found in features.
# Image ID 94340 not found in features.
# Image ID 548141 not found in features.
# Image ID 388031 not found in features.
# Image ID 130175 not found in features.
# Image ID 273491 not found in features.
# Image ID 551418 not found in features.
# Image ID 494285 not found in features.
# Image ID 411474 not found in features.
# Image ID 496192 not found in features.
# Image ID 298299 not found in features.
# Image ID 200735 not found in features.
# Image ID 80937 not found in features.
# Image ID 3999 not found in features.
# Image ID 170785 not found in features.
# Image ID 487514 not found in features.
# Image ID 13471 not found in features.
# Image ID 43049 not found in features.
# Image ID 526701 not found in features.
# Image ID 96339 not found in features.
# Image ID 283111 not found in features.
# Image ID 376472 not found in features.
# Image ID 184138 not found in features.
# Image ID 173365 not found in features.
# Image ID 475998 not found in features.
# Image ID 312292 not found in features.
# Image ID 329399 not found in features.
# Image ID 197071 not found in features.
# Image ID 86107 not found in features.
# Image ID 297960 not found in features.
# Image ID 109654 not found in features.
# Image ID 522659 not found in features.
# Image ID 74110 not found in features.
# Image ID 57777 not found in features.
# Image ID 303389 not found in features.
# Image ID 80980 not found in features.
# Image ID 327146 not found in features.
# Image ID 419780 not found in features.
# Image ID 498397 not found in features.
# Image ID 393127 not found in features.
# Image ID 444670 not found in features.
# Image ID 153652 not found in features.
# Image ID 197785 not found in features.
# Image ID 362657 not found in features.
# Image ID 80168 not found in features.
# Image ID 527897 not found in features.
# Image ID 331313 not found in features.
# Image ID 581153 not found in features.
# Image ID 231878 not found in features.
# Image ID 401231 not found in features.
# Image ID 174005 not found in features.
# Image ID 41319 not found in features.
# Image ID 208215 not found in features.
# Image ID 28917 not found in features.
# Image ID 489971 not found in features.
# Image ID 461333 not found in features.
# Image ID 88499 not found in features.
# Image ID 165852 not found in features.
# Image ID 307174 not found in features.
# Image ID 97613 not found in features.
# Image ID 43750 not found in features.
# Image ID 255999 not found in features.
# Image ID 293086 not found in features.
# Image ID 369576 not found in features.
# Image ID 394210 not found in features.
# Image ID 183844 not found in features.
# Image ID 110348 not found in features.
# Image ID 84784 not found in features.
# Image ID 159897 not found in features.
# Image ID 55618 not found in features.
# Image ID 281112 not found in features.
# Image ID 6355 not found in features.
# Image ID 243038 not found in features.
# Image ID 87334 not found in features.
# Image ID 24769 not found in features.
# Image ID 12891 not found in features.
# Image ID 172211 not found in features.
# Image ID 25625 not found in features.
# Image ID 57631 not found in features.
# Image ID 578627 not found in features.
# Image ID 203462 not found in features.
# Image ID 374516 not found in features.
# Image ID 338134 not found in features.
# Image ID 47617 not found in features.
# Image ID 497980 not found in features.
# Image ID 550019 not found in features.
# Image ID 209036 not found in features.
# Image ID 408975 not found in features.
# Image ID 374956 not found in features.
# Image ID 471631 not found in features.
# Image ID 379477 not found in features.
# Image ID 247977 not found in features.
# Image ID 96894 not found in features.
# Image ID 504850 not found in features.
# Image ID 309024 not found in features.
# Image ID 189836 not found in features.
# Image ID 335866 not found in features.
# Image ID 339684 not found in features.
# Image ID 175756 not found in features.
# Image ID 83931 not found in features.
# Image ID 142629 not found in features.
# Image ID 518015 not found in features.
# Image ID 491290 not found in features.
# Image ID 343608 not found in features.
# Image ID 356565 not found in features.
# Image ID 3148 not found in features.
# Image ID 281652 not found in features.
# Image ID 49611 not found in features.
# Image ID 67428 not found in features.
# Image ID 305762 not found in features.
# Image ID 488043 not found in features.
# Image ID 62263 not found in features.
# Image ID 501441 not found in features.
# Image ID 150902 not found in features.
# Image ID 47386 not found in features.
# Image ID 546466 not found in features.
# Image ID 558372 not found in features.
# Image ID 421274 not found in features.
# Image ID 518433 not found in features.
# Image ID 495043 not found in features.
# Image ID 77355 not found in features.
# Image ID 354517 not found in features.
# Image ID 510525 not found in features.
# Image ID 401681 not found in features.
# Image ID 451490 not found in features.
# Image ID 419384 not found in features.
# Image ID 267762 not found in features.
# Image ID 531662 not found in features.
# Image ID 404398 not found in features.
# Image ID 35630 not found in features.
# Image ID 326700 not found in features.
# Image ID 33938 not found in features.
# Image ID 125473 not found in features.
# Image ID 58306 not found in features.
# Image ID 246364 not found in features.
# Image ID 561101 not found in features.
# Image ID 327841 not found in features.
# Image ID 508477 not found in features.
# Image ID 205887 not found in features.
# Image ID 461902 not found in features.
# Image ID 209591 not found in features.
# Image ID 228919 not found in features.
# Image ID 68777 not found in features.
# Image ID 128346 not found in features.
# Image ID 222629 not found in features.
# Image ID 311290 not found in features.
# Image ID 25401 not found in features.
# Image ID 358741 not found in features.
# Image ID 418675 not found in features.
# Image ID 362973 not found in features.
# Image ID 401963 not found in features.
# Image ID 43971 not found in features.
# Image ID 171564 not found in features.
# Image ID 287245 not found in features.
# Image ID 272194 not found in features.
# Image ID 204505 not found in features.
# Image ID 425652 not found in features.
# Image ID 444483 not found in features.
# Image ID 129253 not found in features.
# Image ID 322670 not found in features.
# Image ID 427729 not found in features.
# Image ID 342797 not found in features.
# Image ID 388382 not found in features.
# Image ID 477758 not found in features.
# Image ID 116196 not found in features.
# Image ID 487995 not found in features.
# Image ID 98038 not found in features.
# Image ID 103089 not found in features.
# Image ID 315488 not found in features.
# Image ID 19647 not found in features.
# Image ID 368205 not found in features.
# Image ID 280160 not found in features.
# Image ID 166021 not found in features.
# Image ID 209639 not found in features.
# Image ID 192053 not found in features.
# Image ID 210079 not found in features.
# Image ID 61266 not found in features.
# Image ID 530300 not found in features.
# Image ID 560238 not found in features.
# Image ID 88671 not found in features.
# Image ID 438968 not found in features.
# Image ID 107197 not found in features.
# Image ID 107935 not found in features.
# Image ID 116204 not found in features.
# Image ID 2606 not found in features.
# Image ID 380306 not found in features.
# Image ID 84887 not found in features.
# Image ID 407778 not found in features.
# Image ID 469658 not found in features.
# Image ID 440298 not found in features.
# Image ID 170348 not found in features.
# Image ID 412972 not found in features.
# Image ID 265236 not found in features.
# Image ID 282220 not found in features.
# Image ID 525716 not found in features.
# Image ID 23542 not found in features.
# Image ID 571929 not found in features.
# Image ID 292314 not found in features.
# Image ID 182217 not found in features.
# Image ID 422354 not found in features.
# Image ID 252664 not found in features.
# Image ID 335986 not found in features.
# Image ID 235217 not found in features.
# Image ID 73843 not found in features.
# Image ID 117494 not found in features.
# Image ID 404110 not found in features.
# Image ID 511480 not found in features.
# Image ID 509764 not found in features.
# Image ID 128029 not found in features.
# Image ID 448251 not found in features.
# Image ID 321679 not found in features.
# Image ID 398938 not found in features.
# Image ID 532107 not found in features.
# Image ID 502719 not found in features.
# Image ID 99607 not found in features.
# Image ID 556920 not found in features.
# Image ID 274684 not found in features.
# Image ID 361120 not found in features.
# Image ID 391773 not found in features.
# Image ID 427467 not found in features.
# Image ID 34039 not found in features.
# Image ID 449896 not found in features.
# Image ID 426470 not found in features.
# Image ID 519203 not found in features.
# Image ID 420862 not found in features.
# Image ID 239400 not found in features.
# Image ID 449201 not found in features.
# Image ID 565258 not found in features.
# Image ID 531405 not found in features.
# Image ID 387849 not found in features.
# Image ID 6197 not found in features.
# Image ID 481292 not found in features.
# Image ID 49062 not found in features.
# Image ID 417198 not found in features.
# Image ID 475531 not found in features.
# Image ID 468542 not found in features.
# Image ID 303020 not found in features.
# Image ID 502866 not found in features.
# Image ID 74883 not found in features.
# Image ID 56980 not found in features.
# Image ID 234599 not found in features.
# Image ID 452302 not found in features.
# Image ID 176280 not found in features.
# Image ID 455664 not found in features.
# Image ID 501227 not found in features.
# Image ID 173001 not found in features.
# Image ID 378039 not found in features.
# Image ID 110013 not found in features.
# Image ID 256544 not found in features.
# Image ID 193254 not found in features.
# Image ID 427844 not found in features.
# Image ID 157926 not found in features.
# Image ID 516726 not found in features.
# Image ID 427103 not found in features.
# Image ID 327059 not found in features.
# Image ID 524773 not found in features.
# Image ID 183293 not found in features.
# Image ID 147952 not found in features.
# Image ID 93971 not found in features.
# Image ID 343880 not found in features.
# Image ID 165365 not found in features.
# Image ID 146819 not found in features.
# Image ID 70411 not found in features.
# Image ID 530489 not found in features.
# Image ID 9708 not found in features.
# Image ID 167892 not found in features.
# Image ID 94453 not found in features.
# Image ID 244978 not found in features.
# Image ID 383987 not found in features.
# Image ID 444025 not found in features.
# Image ID 534559 not found in features.
# Image ID 262727 not found in features.
# Image ID 361248 not found in features.
# Image ID 480012 not found in features.
# Image ID 320314 not found in features.
# Image ID 55418 not found in features.
# Image ID 305585 not found in features.
# Image ID 100347 not found in features.
# Image ID 455443 not found in features.
# Image ID 185646 not found in features.
# Image ID 397892 not found in features.
# Image ID 376796 not found in features.
# Image ID 76762 not found in features.
# Image ID 165094 not found in features.
# Image ID 449093 not found in features.
# Image ID 527239 not found in features.
# Image ID 367020 not found in features.
# Image ID 483928 not found in features.
# Image ID 54632 not found in features.
# Image ID 420487 not found in features.
# Image ID 426994 not found in features.
# Image ID 228934 not found in features.
# Image ID 458390 not found in features.
# Image ID 514218 not found in features.
# Image ID 539832 not found in features.
# Image ID 221985 not found in features.
# Image ID 397894 not found in features.
# Image ID 493760 not found in features.
# Image ID 308028 not found in features.
# Image ID 318670 not found in features.
# Image ID 481565 not found in features.
# Image ID 473634 not found in features.
# Image ID 237286 not found in features.
# Image ID 121965 not found in features.
# Image ID 151 not found in features.
# Image ID 507889 not found in features.
# Image ID 30997 not found in features.
# Image ID 579170 not found in features.
# Image ID 19964 not found in features.
# Image ID 136835 not found in features.
# Image ID 61326 not found in features.
# Image ID 420007 not found in features.
# Image ID 41087 not found in features.
# Image ID 163030 not found in features.
# Image ID 183734 not found in features.
# Image ID 426016 not found in features.
# Image ID 343235 not found in features.
# Image ID 334320 not found in features.
# Image ID 324772 not found in features.
# Image ID 422115 not found in features.
# Image ID 193456 not found in features.
# Image ID 335633 not found in features.
# Image ID 554737 not found in features.
# Image ID 274663 not found in features.
# Image ID 313993 not found in features.
# Image ID 80363 not found in features.
# Image ID 132515 not found in features.
# Image ID 32236 not found in features.
# Image ID 318462 not found in features.
# Image ID 262704 not found in features.
# Image ID 175523 not found in features.
# Image ID 499541 not found in features.
# Image ID 199570 not found in features.
# Image ID 188459 not found in features.
# Image ID 400313 not found in features.
# Image ID 447688 not found in features.
# Image ID 185006 not found in features.
# Image ID 254604 not found in features.
# Image ID 357537 not found in features.
# Image ID 115311 not found in features.
# Image ID 202991 not found in features.
# Image ID 405677 not found in features.
# Image ID 484992 not found in features.
# Image ID 312946 not found in features.
# Image ID 457555 not found in features.
# Image ID 232118 not found in features.
# Image ID 376492 not found in features.
# Image ID 377329 not found in features.
#  85%|██████████████████████████▍    | 100863/118287 [00:00<00:00, 227610.58it/s]IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Train the LSTM model
X1train, X2train, ytrain = [], [], []
for img_id, cap_list in tqdm(captions.items()):
    img_features = features[img_id]
    X1, X2, y = create_sequences(tokenizer, max_length, cap_list, img_features)
    X1train.extend(X1)
    X2train.extend(X2)
    ytrain.extend(y)

X1train, X2train, ytrain = np.array(X1train), np.array(X2train), np.array(ytrain)

lstm_model.fit([X1train, X2train], ytrain, epochs=20, batch_size=64)
gru_model.fit([X1train, X2train], ytrain, epochs=20, batch_size=64)
# Out:
#   0%|                                                | 0/118287 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       2 X1train, X2train, ytrain = [], [], []
#       3 for img_id, cap_list in tqdm(captions.items()):
# ----> 4     img_features = features[img_id]
#       5     X1, X2, y = create_sequences(tokenizer, max_length, cap_list, img_features)
#       6     X1train.extend(X1)
#
# KeyError: 203564

# %%
def generate_caption(model, tokenizer, photo, max_length):
    in_text = 'startseq'
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_length)
        yhat = model.predict([photo, sequence], verbose=0)
        yhat = np.argmax(yhat)
        word = tokenizer.index_word[yhat]
        if word is None:
            break
        in_text += ' ' + word
        if word == 'endseq':
            break
    return in_text

# Test on sample images
for img_id in list(captions.keys())[:5]:
    caption = generate_caption(lstm_model, tokenizer, features[img_id].reshape(1, 2048), max_length)
    print("LSTM Caption:", caption)
    caption = generate_caption(gru_model, tokenizer, features[img_id].reshape(1, 2048), max_length)
    print("GRU Caption:", caption)

# %%
# Calculate BLEU and semantic distance
def evaluate_model(model, tokenizer, photos, captions, max_length):
    actual, predicted = [], []
    for key, desc_list in captions.items():
        y_pred = generate_caption(model, tokenizer, photos[key], max_length)
        references = [d.split() for d in desc_list]
        y_pred = y_pred.split()
        bleu = sentence_bleu(references, y_pred)
        actual.append(references)
        predicted.append(y_pred)
        print(f'BLEU: {bleu:.3f}')
